# %% [markdown]
# We will use the closed form solution to minimise the cost function of a randomly generated set

# %%
import numpy as np
import random
import matplotlib.pyplot as plt

# %%
np.random.seed(43)
X = 3*np.random.rand(100,1)
y = 4 + 3*X +2*np.random.randn(100,1)

# %%
plt.scatter(X,y)

# %%
y.shape

# %%
X_b = np.c_[np.ones((100, 1)), X] # add x0 = 1 to each instance

# %%
theta_best = np.linalg.inv(X_b.T.dot(X_b)).dot(X_b.T).dot(y)

# %%
theta_best

# %%
X_new = np.array([[0],[3]])

# %%
X_plot = np.linspace(0, 3, 100).reshape(-1,2)
X_plot_b = np.c_[np.ones((100,1)), X_plot]
y_plot = X_plot_b @ theta_best
plt.plot(X_plot, y_plot, 'r-')
plt.plot(X, y, "b.")
plt.axis([0, 2, 0, 15])

# %%
X = 3*np.random.rand(100,1)
y = 4 + 3*X +2*np.random.randn(100,1)

# %%
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
def plot_learning_curves(model, X, y):
    X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.2)
    train_errors, val_errors = [], []
    for m in range(1, len(X_train)):
        model.fit(X_train[:m], y_train[:m])
        y_train_predict = model.predict(X_train[:m])
        y_val_predict = model.predict(X_val)
        train_errors.append(mean_squared_error(y_train_predict, y_train[:m]))
        val_errors.append(mean_squared_error(y_val_predict, y_val))
    plt.plot(np.sqrt(train_errors), "r-+", linewidth=2, label="train")
    plt.plot(np.sqrt(val_errors), "b-", linewidth=3, label="val")
